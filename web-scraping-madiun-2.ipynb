# %%
import pandas as pd
urlmadiun = 'https://dashboard.madiunkota.go.id/'
tabel = pd.read_html(urlmadiun)


tabel1 = pd.concat(tabel)
tabel1
# Out:
#     No         NAMA KEL  PELAKU PERJALANAN  KONTAK ERAT  SUSPECT  PROBABLE  \
# 0    1        BANJAREJO                137          240      NaN       NaN
# 1    2         DEMANGAN                 91          284      NaN       2.0
# 2    3          JOSENAN                 56          176      NaN       NaN
# 3    4         KANIGORO                 78          231      NaN       2.0
# 4    5       KARTOHARJO                 47           79      NaN       1.0
# 5    6          KEJURON                 84          229      NaN       1.0
# 6    7            KELUN                 38          122      NaN       NaN
# 7    8           KLEGEN                 51          282      NaN       NaN
# 8    9           KUNCEN                  8            9      NaN       NaN
# 9   10       MADIUN LOR                 80          200      NaN       NaN
# 10  11       MANGUHARJO                 37          134      NaN       1.0
# 11  12        MANISREJO                105          419      NaN       1.0
# 12  13         MOJOREJO                101          362      NaN       NaN
# 13  14  NAMBANGAN KIDUL                 56          224      NaN       NaN
# 14  15    NAMBANGAN LOR                147          275      NaN       1.0
# 15  16          NGEGONG                 36          123      NaN       NaN
# 16  17     ORO-ORO OMBO                 46          157      NaN       2.0
# 17  18          PANDEAN                 92          169      2.0       NaN
# 18  19     PANGONGANGAN                 25           53      NaN       1.0
# 19  20          PATIHAN                 45           95      NaN       1.0
# 20  21      PILANGBANGO                 47           91      NaN       NaN
# 21  22        REJOMULYO                 93          354      NaN       2.0
# 22  23          SOGATEN                 65          165      NaN       NaN
# 23  24         SUKOSARI                 70          103      NaN       NaN
# 24  25            TAMAN                 64          303      NaN       NaN
# 25  26       TAWANGREJO                 39          126      NaN       1.0
# 26  27          WINONGO                 67          212      NaN       NaN
#
#     KONFIRMASI  SEMBUH  DIRAWAT  ISOLASI MANDIRI  MENINGGAL  \
# 0          194     161     13.0             12.0          8
# 1          187     146     10.0             24.0          7
# 2          140      92     16.0             24.0          8
# 3          246     184     25.0             24.0         13
# 4           81      63     13.0              NaN          5
# 5          199     163      9.0              9.0         18
# 6          112      92      7.0              6.0          7
# 7          246     194     16.0             17.0         19
# 8           12       6      NaN              4.0          2
# 9          195     151     12.0             14.0         18
# 10          89      72      8.0              2.0          7
# 11         352     286     30.0             19.0         17
# 12         271     227     16.0             13.0         15
# 13         191     131     26.0             26.0          8
# 14         171     122     20.0             16.0         13
# 15          39      32      3.0              1.0          3
# 16         108      81      9.0             13.0          5
# 17         262     184     11.0             51.0         16
# 18          78      64      9.0              2.0          3
# 19          92      66      6.0             14.0          6
# 20          76      65      5.0              2.0          4
# 21         268     215     16.0             17.0         20
# 22         152     123     15.0              9.0          5
# 23          67      60      2.0              2.0          3
# 24         235     165     15.0             42.0         13
# 25          77      63      7.0              1.0          6
# 26         251     213     14.0             12.0         12
#
#    PROSENTASE KESEMBUHAN
# 0          82.98969072 %
# 1                78.07 %
# 2          65.71428571 %
# 3          74.79674797 %
# 4          77.77777778 %
# 5          81.90954774 %
# 6                82.14 %
# 7                78.86 %
# 8                   50 %
# 9          77.43589744 %
# 10                80.9 %
# 11               81.25 %
# 12         83.76383764 %
# 13               68.59 %
# 14               71.35 %
# 15         82.05128205 %
# 16                  75 %
# 17               70.23 %
# 18               82.05 %
# 19         71.73913043 %
# 20               85.53 %
# 21               80.22 %
# 22         80.92105263 %
# 23         89.55223881 %
# 24               70.21 %
# 25               81.82 %
# 26               84.86 %

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime as dt

# %%
driver = webdriver.Chrome("C:/Users/Okta/Downloads/Compressed/chromedriver")
source = 'https://dashboard.madiunkota.go.id/'
driver.get(source)
driver.find_element_by_xpath('//*[@class="dataTables_wrapper no-footer"]/div[1]/div/label/select/option[@value ="50"]').click()

content = driver.page_source
soup = BeautifulSoup(content)
div = soup.find('table', class_='table table-bordered table-hover datatable-basic dataTable no-footer')
links = div.find_all('td')

# %%
import numpy as np

# %%
#find time and date
date = soup.find('div',class_ = 'panel panel-body bg-warning-400 has-bg-image')
date1 = date.find('span')

a = date.text[266:279].split()
a

bulan = ['januari', 'februari', 'maret', 'april', 'mei', 'juni','juli','agustus', 'september', 'oktober','november','desember']

bln = bulan.index(a[1].lower())+1

date_update = a[2]+'-'+str(bln)+'-'+a[0]
date_update = dt.strptime(date_update, '%Y-%m-%d').strftime('%Y-%m-%d')

now = dt.now().strftime('%Y-%m-%d')

# %% [markdown]
# ### Bikin tabel

# %%
df = pd.DataFrame()

# %%
# scrape_date & source link
scrape_date = []
source_link = []

for i, link in enumerate(links):
    if i in range(1, len(links), 12):
        scrape_date.append(now)
    if i in range(1, len(links), 12):
        source_link.append(source)

# %%
provinsi = []

for i, link in enumerate(links):
    if i in range(1, len(links), 12):
        provinsi.append('Jawa Timur')

# %%
kabkot = []

for i, link in enumerate(links):
    if i in range(1, len(links), 12):
        kabkot.append('Kota Madiun')

# %%
kelurahanraw = tabel1['NAMA KEL']
kelurahan = kelurahanraw.tolist()

# %%
suspect = tabel1['SUSPECT']
probable = tabel1['PROBABLE']

suspect = suspect.tolist()
probable = probable.tolist()

total_pdp = suspect + probable

# %%
total_odp = tabel1['KONTAK ERAT'].tolist()

# %%
positif_sembuh = tabel1['SEMBUH'].tolist()
positif_dirawat = tabel1['DIRAWAT'].tolist()
positif_isolasi = tabel1['ISOLASI MANDIRI'].tolist()
positif_meninggal = tabel1['MENINGGAL'].tolist()

# %%
total_positif1 = [positif_sembuh, positif_dirawat, positif_isolasi, positif_meninggal]
total_positif1 = [sum(x) for x in zip(*total_positif1)]

# %%
types = []

for i, link in enumerate(links):
    if i in range(1, len(links), 12):
        types.append('kelurahan')

# %%
user_pic = []

for i, link in enumerate(links):
    if i in range(1, len(links), 12):
        user_pic.append('octa')

# %%
kecamatan = []

for i, link in enumerate(links):
    if i in range(1, len(links), 12):
        kecamatan.append('0')

# %%
len(kecamatan)
# Out:
# 27

# %%
#create table
df['scrape_date'] = scrape_date 
df['date_update'] = date_update 
df['provinsi'] = provinsi 
df['kabkot'] = kabkot 
df['kecamatan'] = kecamatan
df['kelurahan'] = kelurahan 
df['total_pdp'] = total_pdp1
df['total_odp'] = total_odp 
df['positif_sembuh'] = positif_sembuh 
df['positif_dirawat'] = positif_dirawat 
df['positif_isolasi'] = positif_isolasi 
df['positif_meninggal'] = positif_meninggal 
df['source_link'] = source_link 
df['types'] = types 
df['user_pic'] = user_pic

# %%
total_positif = df['positif_sembuh'] + df['positif_dirawat'] + df['positif_isolasi'] + df['positif_meninggal']
total_positif = total_positif.tolist()

df.insert(8,column='total_positif', value=total_positif)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-194-d0d4001be524> in <module>
#       2 total_positif = total_positif.tolist()
#       3
# ----> 4 df.insert(8,column='total_positif', value=total_positif)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3574         self._ensure_valid_index(value)
#    3575         value = self._sanitize_column(column, value, broadcast=False)
# -> 3576         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3577
#    3578     def assign(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
#    1172             # Should this be a different kind of error??
# -> 1173             raise ValueError("cannot insert {}, already exists".format(item))
#    1174
#    1175         if not isinstance(loc, int):
#
# ValueError: cannot insert total_positif, already exists

# %%
df.loc[df['kelurahan'] == 'KANIGORO', 'kecamatan'] = 'Kartoharjo' 
df.loc[df['kelurahan'] == 'KELUN', 'kecamatan'] = 'Kartoharjo' 
df.loc[df['kelurahan'] == 'KARTOHARJO', 'kecamatan'] = 'Kartoharjo' 
df.loc[df['kelurahan'] == 'KLEGEN', 'kecamatan'] = 'Kartoharjo' 
df.loc[df['kelurahan'] == 'ORO-ORO OMBO', 'kecamatan'] = 'Kartoharjo' 
df.loc[df['kelurahan'] == 'PILANGBANGO', 'kecamatan'] = 'Kartoharjo' 
df.loc[df['kelurahan'] == 'REJOMULYO', 'kecamatan'] = 'Kartoharjo' 
df.loc[df['kelurahan'] == 'SUKOSARI', 'kecamatan'] = 'Kartoharjo' 
df.loc[df['kelurahan'] == 'TAWANGREJO', 'kecamatan'] = 'Kartoharjo' 

df.loc[df['kelurahan'] == 'MADIUN LOR', 'kecamatan'] = 'Manguharjo' 
df.loc[df['kelurahan'] == 'MANGUHARJO', 'kecamatan'] = 'Manguharjo' 
df.loc[df['kelurahan'] == 'NAMBANGAN KIDUL', 'kecamatan'] = 'Manguharjo' 
df.loc[df['kelurahan'] == 'NAMBANGAN LOR', 'kecamatan'] = 'Manguharjo' 
df.loc[df['kelurahan'] == 'NGEGONG', 'kecamatan'] = 'Manguharjo' 
df.loc[df['kelurahan'] == 'PANGONGANGAN', 'kecamatan'] = 'Manguharjo' 
df.loc[df['kelurahan'] == 'PATIHAN', 'kecamatan'] = 'Manguharjo' 
df.loc[df['kelurahan'] == 'SOGATEN', 'kecamatan'] = 'Manguharjo' 
df.loc[df['kelurahan'] == 'WINONGO', 'kecamatan'] = 'Manguharjo' 

df.loc[df['kelurahan'] == 'BANJAREJO', 'kecamatan'] = 'Taman' 
df.loc[df['kelurahan'] == 'DEMANGAN', 'kecamatan'] = 'Taman' 
df.loc[df['kelurahan'] == 'JOSENAN', 'kecamatan'] = 'Taman' 
df.loc[df['kelurahan'] == 'KEJURON', 'kecamatan'] = 'Taman' 
df.loc[df['kelurahan'] == 'KUNCEN', 'kecamatan'] = 'Taman' 
df.loc[df['kelurahan'] == 'MOJOREJO', 'kecamatan'] = 'Taman' 
df.loc[df['kelurahan'] == 'MANISREJO', 'kecamatan'] = 'Taman' 
df.loc[df['kelurahan'] == 'PANDEAN', 'kecamatan'] = 'Taman' 
df.loc[df['kelurahan'] == 'TAMAN', 'kecamatan'] = 'Taman'

# %%
df
# Out:
#    scrape_date date_update    provinsi       kabkot   kecamatan  \
# 0   2021-07-17  2021-07-17  Jawa Timur  Kota Madiun       Taman
# 1   2021-07-17  2021-07-17  Jawa Timur  Kota Madiun       Taman
# 2   2021-07-17  2021-07-17  Jawa Timur  Kota Madiun       Taman
# 3   2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Kartoharjo
# 4   2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Kartoharjo
# 5   2021-07-17  2021-07-17  Jawa Timur  Kota Madiun       Taman
# 6   2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Kartoharjo
# 7   2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Kartoharjo
# 8   2021-07-17  2021-07-17  Jawa Timur  Kota Madiun       Taman
# 9   2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Manguharjo
# 10  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Manguharjo
# 11  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun       Taman
# 12  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun       Taman
# 13  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Manguharjo
# 14  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Manguharjo
# 15  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Manguharjo
# 16  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Kartoharjo
# 17  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun       Taman
# 18  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Manguharjo
# 19  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Manguharjo
# 20  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Kartoharjo
# 21  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Kartoharjo
# 22  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Manguharjo
# 23  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Kartoharjo
# 24  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun       Taman
# 25  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Kartoharjo
# 26  2021-07-17  2021-07-17  Jawa Timur  Kota Madiun  Manguharjo
#
#           kelurahan  total_pdp  total_odp  total_positif  positif_sembuh  \
# 0         BANJAREJO        NaN        240          194.0             161
# 1          DEMANGAN        NaN        284          187.0             146
# 2           JOSENAN        NaN        176          140.0              92
# 3          KANIGORO        NaN        231          246.0             184
# 4        KARTOHARJO        NaN         79            NaN              63
# 5           KEJURON        NaN        229          199.0             163
# 6             KELUN        NaN        122          112.0              92
# 7            KLEGEN        NaN        282          246.0             194
# 8            KUNCEN        NaN          9            NaN               6
# 9        MADIUN LOR        NaN        200          195.0             151
# 10       MANGUHARJO        NaN        134           89.0              72
# 11        MANISREJO        NaN        419          352.0             286
# 12         MOJOREJO        NaN        362          271.0             227
# 13  NAMBANGAN KIDUL        NaN        224          191.0             131
# 14    NAMBANGAN LOR        NaN        275          171.0             122
# 15          NGEGONG        NaN        123           39.0              32
# 16     ORO-ORO OMBO        NaN        157          108.0              81
# 17          PANDEAN        NaN        169          262.0             184
# 18     PANGONGANGAN        NaN         53           78.0              64
# 19          PATIHAN        NaN         95           92.0              66
# 20      PILANGBANGO        NaN         91           76.0              65
# 21        REJOMULYO        NaN        354          268.0             215
# 22          SOGATEN        NaN        165          152.0             123
# 23         SUKOSARI        NaN        103           67.0              60
# 24            TAMAN        NaN        303          235.0             165
# 25       TAWANGREJO        NaN        126           77.0              63
# 26          WINONGO        NaN        212          251.0             213
#
#     positif_dirawat  positif_isolasi  positif_meninggal  \
# 0              13.0             12.0                  8
# 1              10.0             24.0                  7
# 2              16.0             24.0                  8
# 3              25.0             24.0                 13
# 4              13.0              NaN                  5
# 5               9.0              9.0                 18
# 6               7.0              6.0                  7
# 7              16.0             17.0                 19
# 8               NaN              4.0                  2
# 9              12.0             14.0                 18
# 10              8.0              2.0                  7
# 11             30.0             19.0                 17
# 12             16.0             13.0                 15
# 13             26.0             26.0                  8
# 14             20.0             16.0                 13
# 15              3.0              1.0                  3
# 16              9.0             13.0                  5
# 17             11.0             51.0                 16
# 18              9.0              2.0                  3
# 19              6.0             14.0                  6
# 20              5.0              2.0                  4
# 21             16.0             17.0                 20
# 22             15.0              9.0                  5
# 23              2.0              2.0                  3
# 24             15.0             42.0                 13
# 25              7.0              1.0                  6
# 26             14.0             12.0                 12
#
#                             source_link      types user_pic
# 0   https://dashboard.madiunkota.go.id/  kelurahan     octa
# 1   https://dashboard.madiunkota.go.id/  kelurahan     octa
# 2   https://dashboard.madiunkota.go.id/  kelurahan     octa
# 3   https://dashboard.madiunkota.go.id/  kelurahan     octa
# 4   https://dashboard.madiunkota.go.id/  kelurahan     octa
# 5   https://dashboard.madiunkota.go.id/  kelurahan     octa
# 6   https://dashboard.madiunkota.go.id/  kelurahan     octa
# 7   https://dashboard.madiunkota.go.id/  kelurahan     octa
# 8   https://dashboard.madiunkota.go.id/  kelurahan     octa
# 9   https://dashboard.madiunkota.go.id/  kelurahan     octa
# 10  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 11  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 12  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 13  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 14  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 15  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 16  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 17  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 18  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 19  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 20  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 21  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 22  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 23  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 24  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 25  https://dashboard.madiunkota.go.id/  kelurahan     octa
# 26  https://dashboard.madiunkota.go.id/  kelurahan     octa
